# %% [markdown]
# 1.0 Trained data on Yolov8n for 10 epochs!

# %%
import os
from IPython.display import display, Image
from IPython import display
from ultralytics import YOLO

# %%
display.clear_output()
# !yolo checks
# Out:
# Ultralytics YOLOv8.1.24 🚀 Python-3.9.0 torch-2.3.0.dev20231217 CPU (Apple M1 Max)
# Setup complete ✅ (10 CPUs, 64.0 GB RAM, 610.8/1858.2 GB disk)
#
# OS                  macOS-14.3.1-arm64-arm-64bit
# Environment         Darwin
# Python              3.9.0
# Install             pip
# RAM                 64.00 GB
# CPU                 Apple M1 Max
# CUDA                None
#
# matplotlib          ✅ 3.8.2>=3.3.0
# opencv-python       ✅ 4.8.1.78>=4.6.0
# pillow              ✅ 10.1.0>=7.1.2
# pyyaml              ✅ 6.0.1>=5.3.1
# requests            ✅ 2.31.0>=2.23.0
# scipy               ✅ 1.11.4>=1.4.1
# torch               ✅ 2.3.0.dev20231217>=1.8.0
# torchvision         ✅ 0.18.0.dev20231217>=0.9.0
# tqdm                ✅ 4.66.1>=4.64.0
# psutil              ✅ 5.9.6
# py-cpuinfo          ✅ 9.0.0
# thop                ✅ 0.1.1-2209072238>=0.1.1
# pandas              ✅ 2.1.4>=1.1.4
# seaborn             ✅ 0.13.1>=0.11.0

# %%
# !yolo task=detect mode=train model=yolov8n.pt data="data/data.yml" epochs=10 imgsz=640
# Out:
# ...
# 100%|██████████████████████████████████████| 6.23M/6.23M [00:00<00:00, 20.7MB/s]
# Ultralytics YOLOv8.1.24 🚀 Python-3.9.0 torch-2.3.0.dev20231217 CPU (Apple M1 Max)
# ...

# %%
Image (filename=f'runs/detect/train8/confusion_matrix.png', width=600)

# %%
Image (filename=f'runs/detect/train8/results.png', width=600)

# %%
# !yolo task=detect mode=val model="runs/detect/train8/weights/best.pt" data="data/data.yml"
# Out:
# Ultralytics YOLOv8.1.24 🚀 Python-3.9.0 torch-2.3.0.dev20231217 CPU (Apple M1 Max)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /Users/work/Desktop/BuroHappold/Task/data/valid/labels.cache... 51
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        517      14431      0.845       0.82      0.881      0.622
#                   door        517       5470      0.881      0.893      0.926      0.659
#                 window        517       3584      0.822      0.764       0.84      0.484
#                   zone        517       5377      0.832      0.802      0.876      0.721
# Speed: 0.5ms preprocess, 213.2ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=predict model="runs/detect/train8/weights/best.pt" conf=0.6 source="data/test/images"
# Out:
# Ultralytics YOLOv8.1.24 🚀 Python-3.9.0 torch-2.3.0.dev20231217 CPU (Apple M1 Max)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/255 /Users/work/Desktop/BuroHappold/Task/data/test/images/1010_png.rf.cf3c8ce678e7dc00f7d5f0921f439858.jpg: 640x640 2 doors, 5 zones, 88.0ms
# image 2/255 /Users/work/Desktop/BuroHappold/Task/data/test/images/1012_png.rf.fd3d80c9e721a4e8b0c369a9be397af6.jpg: 640x640 2 doors, 1 zone, 70.1ms
# image 3/255 /Users/work/Desktop/BuroHappold/Task/data/test/images/1014_png.rf.6b088752e5649eeeb7334ff08996d2a2.jpg: 640x640 7 doors, 3 windows, 5 zones, 72.3ms
# image 4/255 /Users/work/Desktop/BuroHappold/Task/data/test/images/1143_png.rf.544ecf6ffbb324793578c26f04af7760.jpg: 640x640 7 doors, 4 windows, 6 zones, 67.5ms
# image 5/255 /Users/work/Desktop/BuroHappold/Task/data/test/images/1156_png.rf.d6b44f9ce1e99ca6a440a33c88714242.jpg: 640x640 7 doors, 2 windows, 5 zones, 67.3ms
# ...
