# %% [markdown]
# ### Predictions from First model trained on Yolov8s

# %%
import glob
from IPython.display import Image, display

for idx, image_path in enumerate(glob.glob('runs/detect/predict/*.jpg'), start=1):
    if idx <= 10:
        display(Image(filename=image_path, height=600))
        print("\n")
    else:
        break
